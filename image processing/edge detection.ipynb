# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("./images/line-detection-4.jpg") #load img

# convert it to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# show the grayscale image
# plt.imshow(gray, cmap="gray")
# plt.show()

# %%
# Canny edge detector is an edge detection operator that uses multi-stage algorithm to detect a wide range of edges in images.

# Filtering out noise using *Gaussian blur algorithm.
# Finding the strength and direction of edges using *Sobel Filters.
# Isolating the strongest edges and thin them to one-pixel wide lines by applying non-maximum suppression.
# Using *hysteresis to isolate the best edges.


# perform the canny edge detector to detect image edges
# edges = cv2.Canny(gray, threshold1=30, threshold2=100)
sobelx = cv2.Sobel(image,cv2.CV_64F,1,0,ksize=5)
# The smallest value between threshold1 and threshold2 is used for edge linking. 
# The largest value is used to find initial segments of strong edges.

# show the edges image
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20, 20))
ax1.imshow(image)
ax1.set_title('Original Image')
ax1.axis('off')

ax2.imshow(sobelx, cmap='gray')
ax2.set_title('Edge Image')
ax2.axis('off')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (-0.5, 812.5, 799.5, -0.5)

# %%
# 2nd example

image_2 = cv2.imread("./images/road.jpg") # load image in grayscale

gray_image = cv2.cvtColor(image_2, cv2.COLOR_RGB2GRAY)
blurredImage = cv2.GaussianBlur(gray_image, (5, 5), 0)
edgeImage = cv2.Canny(blurredImage, 50, 120)


# show the edges image
# plt.imshow(edgeImage, cmap="gray")
# plt.show()

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20, 20))
ax1.imshow(image_2)
ax1.set_title('Original Image')
ax1.axis('off')

ax2.imshow(edgeImage, cmap='gray')
ax2.set_title('Edge Image')
ax2.axis('off')
# Out:
# (-0.5, 863.5, 319.5, -0.5)

# %%
# 3rd exmple

img0 = cv2.imread('./images/SanFrancisco.jpg',)
# converting to gray scale
gray = cv2.cvtColor(img0, cv2.COLOR_BGR2GRAY)

# remove noise
img = cv2.GaussianBlur(gray,(3,3),0)

# convolute with proper kernels
laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)  # x
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)  # y

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=4, ncols=1, figsize=(20, 20))

ax1.imshow(img0)
ax1.set_title('Original Image')
ax1.axis('off')

ax2.imshow(laplacian, cmap='gray')
ax2.set_title('Laplacian Image')
ax2.axis('off')

ax3.imshow(sobelx, cmap='gray')
ax3.set_title('Sobel X Image')
ax3.axis('off')
 
ax4.imshow(sobely, cmap='gray')
ax4.set_title('Sobel Y Image')
ax4.axis('off')
# Out:
# (-0.5, 299.5, 167.5, -0.5)
