# %%
import os
import pandas as pd
# os.listdir()

# %%
df1 = pd.read_csv('supermarkets.csv')
# df1.columns = ['Id','Address','city','state','Country','nam','Employees']    
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# df2 = pd.read_csv('supermarkets.json')
df2 = pd.read_json('supermarkets.json')
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df3 = pd.read_excel('supermarkets.xlsx')
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pd.read_csv('supermarkets-commas.txt')
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pd.read_csv('supermarkets-semi-colons.txt',sep=';')
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1.loc['735 Dolores St':'3995 23rd St','State':'Employees']
df1.loc['2':'5','State':'Employees']
# Out:
#               State Country         Name  Employees
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df1.set_index('Address')
df1.loc['735 Dolores St':'3995 23rd St','State':'Employees']
# Out:
# Empty DataFrame
# Columns: [State, Country, Name, Employees]
# Index: []

# %%
df1 = df1.set_index("State")
df1
# Out:
#                   ID           City Country         Name  Employees
# State
# CA 94114           1  San Francisco     USA      Madeira          8
# CA 94119           2  San Francisco     USA  Bready Shop         15
# California 94114   3  San Francisco     USA  Super River         25
# CA 94114           4  San Francisco     USA   Ben's Shop         10
# California         5  San Francisco     USA      Sanchez         12
# CA 94114           6  San Francisco     USA   Richvalley         20

# %%
df1.iloc[2,1:4]
# Out:
# City       San Francisco
# Country              USA
# Name         Super River
# Name: California 94114, dtype: object

# %%
df1.iloc[3,0]
# Out:
# 4

# %%
# geocode example
from geopy.geocoders import ArcGIS
nom = ArcGIS()
n =nom.geocode('3666 21st St, San Fransisco, CA 94114')
n
# Out:
# Location((37.7566480114, -122.42937497, 0.0))

# %%
# from geopy.geocoders import Nominatim
# nom = Nominatim()
# nom.geocode('3666 21st St, San Fransisco, CA 94114')

# %%
df = pd.read_csv('supermarkets.csv')
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df['Address']=df['Address']+", "+ df['City']+", " + df['Country']
df
# Out:
#    ID                              Address           City             State  \
# 0   1     3666 21st St, San Francisco, USA  San Francisco          CA 94114
# 1   2   735 Dolores St, San Francisco, USA  San Francisco          CA 94119
# 2   3      332 Hill St, San Francisco, USA  San Francisco  California 94114
# 3   4     3995 23rd St, San Francisco, USA  San Francisco          CA 94114
# 4   5  1056 Sanchez St, San Francisco, USA  San Francisco        California
# 5   6  551 Alvarado St, San Francisco, USA  San Francisco          CA 94114
#
#   Country         Name  Employees
# 0     USA      Madeira          8
# 1     USA  Bready Shop         15
# 2     USA  Super River         25
# 3     USA   Ben's Shop         10
# 4     USA      Sanchez         12
# 5     USA   Richvalley         20

# %%
df['Coordinates'] = df['Address'].apply(nom.geocode)
df
# Out:
#    ID                              Address           City             State  \
# 0   1     3666 21st St, San Francisco, USA  San Francisco          CA 94114
# 1   2   735 Dolores St, San Francisco, USA  San Francisco          CA 94119
# 2   3      332 Hill St, San Francisco, USA  San Francisco  California 94114
# 3   4     3995 23rd St, San Francisco, USA  San Francisco          CA 94114
# 4   5  1056 Sanchez St, San Francisco, USA  San Francisco        California
# 5   6  551 Alvarado St, San Francisco, USA  San Francisco          CA 94114
#
#   Country         Name  Employees  \
# 0     USA      Madeira          8
# 1     USA  Bready Shop         15
# 2     USA  Super River         25
# 3     USA   Ben's Shop         10
# 4     USA      Sanchez         12
# 5     USA   Richvalley         20
#
#                                          Coordinates
# 0  (3666 21st St, San Francisco, California, 9411...
# 1  (735 Dolores St, San Francisco, California, 94...
# ...

# %%
df.Coordinates[0]
# Out:
# Location((37.7566480114, -122.42937497, 0.0))

# %%
df['Latitude'] = df['Coordinates'].apply(lambda x:x.latitude if x != None else None)
df['Longitude'] = df['Coordinates'].apply(lambda x:x.longitude if x != None else None)
df
# Out:
#    ID                              Address           City             State  \
# 0   1     3666 21st St, San Francisco, USA  San Francisco          CA 94114
# 1   2   735 Dolores St, San Francisco, USA  San Francisco          CA 94119
# 2   3      332 Hill St, San Francisco, USA  San Francisco  California 94114
# 3   4     3995 23rd St, San Francisco, USA  San Francisco          CA 94114
# 4   5  1056 Sanchez St, San Francisco, USA  San Francisco        California
# 5   6  551 Alvarado St, San Francisco, USA  San Francisco          CA 94114
#
#   Country         Name  Employees  \
# 0     USA      Madeira          8
# 1     USA  Bready Shop         15
# 2     USA  Super River         25
# 3     USA   Ben's Shop         10
# 4     USA      Sanchez         12
# 5     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# 0  (3666 21st St, San Francisco, California, 9411...  37.756648 -122.429375
# ...
